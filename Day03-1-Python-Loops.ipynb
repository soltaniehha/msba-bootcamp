# %% [markdown]
# # Day 3: Python Loops
# ## Lecture Notebook
#
# This notebook is for live coding on loops. We'll iterate with `for` and `while`, compare when to use each, and practice common patterns.
#
# ---

# %%
# Run this cell first if you want to use the hints in this notebook
from IPython.display import Pretty as disp
hint = 'hints/'  # hint files live in this repo's hints/ folder

# %% [markdown]
# ## Goals for This Session
# - Iterate lists and ranges with `for`
# - Control repetition and termination with `while`
# - Choose the right loop for the job
#
# ---

# %% [markdown]
# ## Part 1: For Loops
#
# ### Demo 1.1: Iterating Over a List
# Iterate over `orders = [45, 120, 75, 200, 95]` and compute total and count of orders >= 100.

# %%
# Live Code: For Loop over list

# orders = [45, 120, 75, 200, 95]
# total = 0
# high_count = 0
# for ...:
# ...
# print(total, high_count)

# %%
# HINT: Uncomment and execute the cell below to get help
#disp(hint + '03-1-for-loop-list-hint')

# %% [markdown]
# ### Demo 1.2: Range and Index
# Use `range` to iterate indexes for `names = ["Ava", "Ben", "Cara"]` and print each index and name.

# %%
# Live Code: range indices

# names = ["Ava", "Ben", "Cara"]
# for i in range(len(names)):
# print(i, names[i])

# %%
# HINT: Uncomment and execute the cell below to get help
#disp(hint + '03-1-range-index-hint')

# %% [markdown]
# ### In-Class Exercise: FizzBuzz
#
# The most famous interview question in programming. Time to knock it out:
# 1. Loop over the numbers 1 through 20 using `range()`
# 2. For multiples of 3 print `Fizz`, for multiples of 5 print `Buzz`, for multiples of both print `FizzBuzz`, and for everything else print the number itself
# 3. The `%` (remainder) operator is your friend: `n % 3 == 0` asks "is n divisible by 3?"
#
# Rumor has it a surprising share of job applicants can't do this. You are about to be able to.
#
# *Estimated time: 8 minutes*

# %%
# In-Class Exercise: FizzBuzz

# Your code here

# %%
# HINT: Uncomment and execute the cell below to get help
#disp(hint + '03-1-fizzbuzz-hint')

# %% [markdown]
# ## Part 2: While Loops
#
# ### Demo 2.1: Counter with Condition
# Increment a counter until it reaches a limit; print steps.

# %%
# Live Code: while loop counter

# count = 0
# limit = 5
# while ...:
# ...
# print(count)

# %%
# HINT: Uncomment and execute the cell below to get help
#disp(hint + '03-1-while-counter-hint')

# %% [markdown]
# ### Demo 2.2: Input Simulation with Sentinel
# Simulate reading values until `None` is encountered, then stop.

# %%
# Live Code: sentinel loop

# values = [10, 20, None, 30]
# i = 0
# while i < len(values) and values[i] is not None:
# ...
# i += 1

# %%
# HINT: Uncomment and execute the cell below to get help
#disp(hint + '03-1-sentinel-loop-hint')

# %% [markdown]
# ## Part 3: Filtering/Mapping and Flow Control
#
# ### Demo 3.1: Filtering and Mapping
# Use a loop to filter and then map values in a single pass.

# %%
# Live Code: Filtering and Mapping

# prices = [9.99, 25.00, 4.50, 120.00, 49.99]
# filtered = []  # keep prices >= 20
# with_tax = []  # map to price * 1.0825 (example tax)
# ...
# print(filtered)
# print(with_tax)

# %%
# HINT: Uncomment and execute the cell below to get help
#disp(hint + '03-1-filter-map-hint')

# %% [markdown]
# Now let's write a list comprehension that returns a list of prices (with tax) for items >=$20:

# %%
# Live Code: Filtering and Mapping

# %%
# HINT: Uncomment and execute the cell below to get help
#disp(hint + '03-1-list-comprehension-hint')

# %% [markdown]
# ### Demo 3.2: Early Exit and Skips
# Demonstrating `break` to stop early and `continue` to skip items.

# %%
# Live Code: break and continue

# numbers = [3, 7, -1, 10, 0, 5]
# total = 0
# for n in numbers:
# if n < 0:
# break  # early exit on invalid value
# if n == 0:
# continue  # skip zeros
# total += n
# print(total)

# %%
# HINT: Uncomment and execute the cell below to get help
#disp(hint + '03-1-break-continue-hint')
